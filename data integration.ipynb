# %%
pip install pandas numpy matplotlib seaborn scikit-learn pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.6 MB/s eta 0:00:0000:0100:03
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=f82bf013911bbc7a643f813e36eb6722767dbb26c4cca466ae860208834fb1c7
#   Stored in directory: /Users/alijaweddilawari/Library/Caches/pip/wheels/95/13/41/f7f135ee114175605fb4f0a89e7389f3742aa6c1e1a5bcb657
# Successfully built pyspark
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Data Integration Project

#introduction
#Integrating and analysing data help companies to identify patterns, trends and business opportunities that can shape a companies strategy. This project in hand integrates and analyses a data set by using different tools and testing their capabilities. Apache spark has been one of the tools used in this project to analyse the data and create a strategic plan for the company.By leveraging customer demographics and purchasing behavior, the goal is to uncover insights that can enhance product offerings and drive sales strategies.By leveraging customer demographics and purchasing behavior, the goal is to uncover insights that can enhance product offerings and drive sales strategies.By leveraging customer demographics and purchasing behavior, the goal is to uncover insights that can enhance product offerings and drive sales strategies.
#By leveraging customer info, demographics and purchasing behavior, the researcher is uncovering insights that can enhance product offerings and incease sales strategies. The goal for analysing this data is to better understand the customers behaviour and their wants. The data from the selected data set has been cleaned, analysed and integrated to money processes, so it will be easy for the company to work and understand the filter dataset.

#objective: 
The primary objective of this project is to use Apache Spark and its data processing and integration capabilities for the analysation of retail dataset. By performing comprehensive data preprocessing and integration tasks the goal is to uncover and understand valuable data and look into customer demographics and purchasing behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#DATASET with all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data.head(200)  

# the data selected below is collected from online dataset website Kaggle and is the raw form of data ready to be cleaned and processed using Apache spark.
#this dataset for this project contains essential information about customers, including CustomerID, Gender, Age, Annual Income, and Spending Score.
# the attributes in the data said is essential for this project, that's why it's selected.
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
data = pd.read_csv('data int.csv')


print("Original Columns:")
print(data.columns)


print("\nFirst few rows:")
print(data.head(200))


data.dropna(inplace=True)


if 'Quantity' in data.columns and 'UnitPrice' in data.columns:
    
    data = data[(data['Quantity'] > 0) & (data['UnitPrice'] > 0)]
else:
    print("Column 'Quantity' or 'UnitPrice' not found or NA values dropped all rows.")


if 'InvoiceDate' in data.columns:
    
    data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
else:
    print("Column 'InvoiceDate' not found.")


if 'Quantity' in data.columns and 'UnitPrice' in data.columns:
    data['TotalPrice'] = data['Quantity'] * data['UnitPrice']
else:
    print("Column 'Quantity' or 'UnitPrice' not found.")


if 'Gender' in data.columns:
    female_data = data[data['Gender'] == 'Female']
    male_data = data[data['Gender'] == 'Male']
else:
    print("Column 'Gender' not found.")


print("\nFemale Data:")
print(female_data.head(200))

print("\nMale Data:")
print(male_data.head(200))
# Out:
# Original Columns:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
#
# First few rows:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Female Data (Sample data)
female_data = pd.DataFrame({
    'CustomerID': [3, 4, 5, 6, 7],
    'Gender': ['Female', 'Female', 'Female', 'Female', 'Female'],
    'Age': [20, 23, 31, 22, 35],
    'Annual Income (k$)': [16, 16, 17, 17, 18],
    'Spending Score (1-100)': [6, 77, 40, 76, 6]
})

# Male Data (Sample data)
male_data = pd.DataFrame({
    'CustomerID': [1, 2, 9, 11, 15],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male'],
    'Age': [19, 21, 64, 67, 37],
    'Annual Income (k$)': [15, 15, 19, 19, 20],
    'Spending Score (1-100)': [39, 81, 3, 14, 13]
})

# Group by Age and calculate mean spending score for each group
female_age_groups = female_data.groupby('Age')['Spending Score (1-100)'].mean()
male_age_groups = male_data.groupby('Age')['Spending Score (1-100)'].mean()

# Plotting
plt.figure(figsize=(10, 6))

# Plot for female_data
plt.plot(female_age_groups.index, female_age_groups.values, marker='o', linestyle='-', color='pink', label='Female')
plt.axhline(y=female_age_groups.mean(), color='red', linestyle='--', label=f'Female Mean Score: {female_age_groups.mean():.2f}')

# Plot for male_data
plt.plot(male_age_groups.index, male_age_groups.values, marker='o', linestyle='-', color='blue', label='Male')
plt.axhline(y=male_age_groups.mean(), color='orange', linestyle='--', label=f'Male Mean Score: {male_age_groups.mean():.2f}')

# Title and labels
plt.title('Average Spending Score Trend by Age')
plt.xlabel('Age')
plt.ylabel('Average Spending Score')
plt.legend()

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Female Data (Sample data)
female_data = pd.DataFrame({
    'CustomerID': [3, 4, 5, 6, 7],
    'Gender': ['Female', 'Female', 'Female', 'Female', 'Female'],
    'Age': [20, 23, 31, 22, 35],
    'Annual Income (k$)': [16, 16, 17, 17, 18],
    'Spending Score (1-100)': [6, 77, 40, 76, 6]
})

# Male Data (Sample data)
male_data = pd.DataFrame({
    'CustomerID': [1, 2, 9, 11, 15],
    'Gender': ['Male', 'Male', 'Male', 'Male', 'Male'],
    'Age': [19, 21, 64, 67, 37],
    'Annual Income (k$)': [15, 15, 19, 19, 20],
    'Spending Score (1-100)': [39, 81, 3, 14, 13]
})

# Group by Age and calculate mean spending score for each group
female_age_groups = female_data.groupby('Age')['Spending Score (1-100)'].mean()
male_age_groups = male_data.groupby('Age')['Spending Score (1-100)'].mean()

# Plotting
plt.figure(figsize=(12, 6))

# Plot for female_data (Bar graph)
plt.subplot(1, 2, 1)
female_age_groups.plot(kind='bar', color='pink', label='Average Spending Score')
plt.axhline(y=female_age_groups.mean(), color='red', linestyle='--', label=f'Female Mean Score: {female_age_groups.mean():.2f}')

# Add trend line for females
x_female = female_age_groups.index
y_female = female_age_groups.values
slope_female, intercept_female, _, _, _ = linregress(x_female, y_female)
plt.plot(x_female, slope_female * x_female + intercept_female, color='purple', linestyle='-', label='Trend Line (Female)')

plt.title('Average Spending Score by Age (Female)')
plt.xlabel('Age')
plt.ylabel('Average Spending Score')
plt.legend()

# Plot for male_data (Bar graph)
plt.subplot(1, 2, 2)
male_age_groups.plot(kind='bar', color='blue', label='Average Spending Score')
plt.axhline(y=male_age_groups.mean(), color='orange', linestyle='--', label=f'Male Mean Score: {male_age_groups.mean():.2f}')

# Add trend line for males
x_male = male_age_groups.index
y_male = male_age_groups.values
slope_male, intercept_male, _, _, _ = linregress(x_male, y_male)
plt.plot(x_male, slope_male * x_male + intercept_male, color='green', linestyle='-', label='Trend Line (Male)')

plt.title('Average Spending Score by Age (Male)')
plt.xlabel('Age')
plt.ylabel('Average Spending Score')
plt.legend()

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .getOrCreate()

# %%
pip install pyspark
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load Dataset
data = pd.read_csv('data int.csv')

# %%
# Check column names
print("Original Columns:")
print(data.columns)

# Print first few rows to inspect the structure
print("\nFirst few rows:")
print(data.head(200))
# Out:
# Original Columns:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
#
# First few rows:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# ...

# %%
# Remove missing values
data.dropna(inplace=True)

# %%
# Check again if 'Quantity' and 'UnitPrice' columns exist after dropping NA values
if 'Quantity' in data.columns and 'UnitPrice' in data.columns:
    # Filter based on positive quantities and prices
    data = data[(data['Quantity'] > 0) & (data['UnitPrice'] > 0)]
else:
    print("Column 'Quantity' or 'UnitPrice' not found or NA values dropped all rows.")
# Out:
# Column 'Quantity' or 'UnitPrice' not found or NA values dropped all rows.

# %%
import pandas as pd

# Load Dataset
data = pd.read_csv('data int.csv')

# Check column names and first few rows
print("Original Columns:")
print(data.columns)
print("\nFirst few rows:")
print(data.head(200))
# Out:
# Original Columns:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
#
# First few rows:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# ...

# %%
# Check for missing values
print("\nMissing values in each column:")
print(data.isna().sum())
# Out:
# Missing values in each column:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import pandas as pd

# Load Dataset
data = pd.read_csv('data int.csv')

# Check column names
print("Columns in the dataset:")
print(data.columns)
# Out:
# Columns in the dataset:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
import pandas as pd

# Load Dataset
data = pd.read_csv('data int.csv')

# Check column names
print("Columns in the dataset:")
print(data.columns)

# Display first few rows to inspect the data
print("\nFirst few rows of the dataset:")
print(data.head(200))

# Handle missing values
data.dropna(inplace=True)  # Drop rows with any missing values

# Convert 'Gender' to a categorical variable
data['Gender'] = data['Gender'].astype('category')

# Convert 'CustomerID' to string to treat it as an identifier
data['CustomerID'] = data['CustomerID'].astype('str')

# Ensure numerical columns are of correct type
data['Age'] = data['Age'].astype('int')
data['Annual Income (k$)'] = data['Annual Income (k$)'].astype('float')
data['Spending Score (1-100)'] = data['Spending Score (1-100)'].astype('int')

# Display the cleaned data
print("\nCleaned Data:")
print(data.head(200))

# Save the cleaned data
data.to_csv('cleaned_data.csv', index=False)
# Out:
# Columns in the dataset:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
#
# First few rows of the dataset:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# ...

# %%
# Uninstall PySpark
# !pip uninstall -y pyspark

# Reinstall PySpark
# !pip install pyspark
# Out:
# Found existing installation: pyspark 3.5.1
# Uninstalling pyspark-3.5.1:
#   Successfully uninstalled pyspark-3.5.1
# ...
#   Using cached pyspark-3.5.1-py2.py3-none-any.whl
# ...

# %%
from pyspark.sql import SparkSession

# Stop the existing Spark session if it exists
try:
    spark.stop()
except:
    pass

# Initialize a new Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.memory", "2g") \
    .getOrCreate()

# Load the cleaned dataset
data_path = "cleaned_data.csv"  # Ensure this path is correct
df = spark.read.csv(data_path, header=True, inferSchema=True)

# Show the first few rows
df.show(200)
# Out:
# +----------+------+---+------------------+----------------------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|
# +----------+------+---+------------------+----------------------+
# |         1|  Male| 19|              15.0|                    39|
# |         2|  Male| 21|              15.0|                    81|
# |         3|Female| 20|              16.0|                     6|
# |         4|Female| 23|              16.0|                    77|
# |         5|Female| 31|              17.0|                    40|
# |         6|Female| 22|              17.0|                    76|
# |         7|Female| 35|              18.0|                     6|
# |         8|Female| 23|              18.0|                    94|
# |         9|  Male| 64|              19.0|                     3|
# |        10|Female| 30|              19.0|                    72|
# |        11|  Male| 67|              19.0|                    14|
# ...

# %%
import os

data_path = "cleaned_data.csv"
if os.path.exists(data_path):
    print("File exists")
else:
    print("File does not exist")
# Out:
# File exists

# %%
df.printSchema()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Annual Income (k$): double (nullable = true)
#  |-- Spending Score (1-100): integer (nullable = true)

# %%
df.describe().show()
# Out:
# +-------+------------------+------+-----------------+------------------+----------------------+
# |summary|        CustomerID|Gender|              Age|Annual Income (k$)|Spending Score (1-100)|
# +-------+------------------+------+-----------------+------------------+----------------------+
# |  count|               200|   200|              200|               200|                   200|
# |   mean|             100.5|  NULL|            38.85|             60.56|                  50.2|
# | stddev|57.879184513951124|  NULL|13.96900733155888| 26.26472116527124|    25.823521668370173|
# |    min|                 1|Female|               18|              15.0|                     1|
# |    max|               200|  Male|               70|             137.0|                    99|
# +-------+------------------+------+-----------------+------------------+----------------------+

# %%
print("Number of rows:", df.count())
# Out:
# Number of rows: 200

# %%
from pyspark.sql.functions import col, sum

# Calculate null counts for each column
null_counts = df.select([sum(col(c).isNull().cast("int")).alias(c) for c in df.columns])

# Convert result to Pandas DataFrame for better visualization
null_counts_pd = null_counts.toPandas().transpose()

# Print the null counts
print("Null Counts:")
print(null_counts_pd)
# Out:
# Null Counts:
#                         0
# CustomerID              0
# Gender                  0
# Age                     0
# Annual Income (k$)      0
# Spending Score (1-100)  0

# %%
# Filter the DataFrame for rows where Age is greater than 30
filtered_data = df.filter(df['Age'] > 30)

# Show the filtered results
filtered_data.show()
# Out:
# +----------+------+---+------------------+----------------------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|
# +----------+------+---+------------------+----------------------+
# |         5|Female| 31|              17.0|                    40|
# |         7|Female| 35|              18.0|                     6|
# |         9|  Male| 64|              19.0|                     3|
# |        11|  Male| 67|              19.0|                    14|
# |        12|Female| 35|              19.0|                    99|
# |        13|Female| 58|              20.0|                    15|
# |        15|  Male| 37|              20.0|                    13|
# |        17|Female| 35|              21.0|                    35|
# |        19|  Male| 52|              23.0|                    29|
# |        20|Female| 35|              23.0|                    98|
# |        21|  Male| 35|              24.0|                    35|
# ...

# %%
grouped_data = df.groupBy('Gender').agg({'Annual Income (k$)': 'mean', 'Spending Score (1-100)': 'max'})

grouped_data.show()
# Out:
# +------+---------------------------+-----------------------+
# |Gender|max(Spending Score (1-100))|avg(Annual Income (k$))|
# +------+---------------------------+-----------------------+
# |Female|                         99|                  59.25|
# |  Male|                         97|      62.22727272727273|
# +------+---------------------------+-----------------------+

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .getOrCreate()

# Load the cleaned dataset
data_path = "cleaned_data.csv"  # Ensure this path is correct
df = spark.read.csv(data_path, header=True, inferSchema=True)

# Add Age Category column
df = df.withColumn('Age Category', when(col('Age') < 30, 'Young').otherwise('Old'))

# Show the result
df.show()
# Out:
# +----------+------+---+------------------+----------------------+------------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|Age Category|
# +----------+------+---+------------------+----------------------+------------+
# |         1|  Male| 19|              15.0|                    39|       Young|
# |         2|  Male| 21|              15.0|                    81|       Young|
# |         3|Female| 20|              16.0|                     6|       Young|
# |         4|Female| 23|              16.0|                    77|       Young|
# |         5|Female| 31|              17.0|                    40|         Old|
# |         6|Female| 22|              17.0|                    76|       Young|
# |         7|Female| 35|              18.0|                     6|         Old|
# |         8|Female| 23|              18.0|                    94|       Young|
# |         9|  Male| 64|              19.0|                     3|         Old|
# ...

# %%
# Save the updated DataFrame to a new CSV file
df.write.csv("processed_data.csv", header=True)

# %%
import os

# Specify the directory where you want to save the CSV file
output_dir = "processed_data_output"

# Save the updated DataFrame to the specified directory
df.write.csv(output_dir, header=True, mode="overwrite")

# Check if the directory has been created
if os.path.exists(output_dir):
    print(f"Directory '{output_dir}' created and CSV files are saved.")
    # List the files in the directory to verify
    files = os.listdir(output_dir)
    print("Files in the directory:")
    for file in files:
        print(file)
else:
    print(f"Failed to create directory '{output_dir}'.")
# Out:
# Directory 'processed_data_output' created and CSV files are saved.
# Files in the directory:
# ._SUCCESS.crc
# _SUCCESS
# part-00000-832b335b-114d-4c59-aae5-f69c569fd23b-c000.csv
# .part-00000-832b335b-114d-4c59-aae5-f69c569fd23b-c000.csv.crc

# %%
# Load the saved CSV file to verify its contents
saved_df = spark.read.csv(os.path.join(output_dir, 'part-00000-832b335b-114d-4c59-aae5-f69c569fd23b-c000.csv'), header=True, inferSchema=True)

# Show the contents of the saved DataFrame
saved_df.show()
# Out:
# +----------+------+---+------------------+----------------------+------------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|Age Category|
# +----------+------+---+------------------+----------------------+------------+
# |         1|  Male| 19|              15.0|                    39|       Young|
# |         2|  Male| 21|              15.0|                    81|       Young|
# |         3|Female| 20|              16.0|                     6|       Young|
# |         4|Female| 23|              16.0|                    77|       Young|
# |         5|Female| 31|              17.0|                    40|         Old|
# |         6|Female| 22|              17.0|                    76|       Young|
# |         7|Female| 35|              18.0|                     6|         Old|
# |         8|Female| 23|              18.0|                    94|       Young|
# |         9|  Male| 64|              19.0|                     3|         Old|
# ...

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .getOrCreate()

# Load the cleaned dataset
data_path = "cleaned_data.csv"  # Ensure this path is correct
df = spark.read.csv(data_path, header=True, inferSchema=True)

# Show schema to verify data types
df.printSchema()

# Show basic statistics
df.describe().show()

# Filter customers older than 30
filtered_data = df.filter(df['Age'] > 30)
filtered_data.show()

# Count the number of male and female customers
gender_count = df.groupBy("Gender").count()
gender_count.show()

# Add Age Category column
df = df.withColumn('Age Category', when(col('Age') < 30, 'Young').otherwise('Old'))

# Show the updated DataFrame
df.show()

# Specify the directory where you want to save the CSV file
output_dir = "processed_data_output"

# Save the updated DataFrame to the specified directory
df.write.csv(output_dir, header=True, mode="overwrite")

# Check if the directory has been created
if os.path.exists(output_dir):
    print(f"Directory '{output_dir}' created and CSV files are saved.")
    # List the files in the directory to verify
    files = os.listdir(output_dir)
    print("Files in the directory:")
    for file in files:
        print(file)
else:
    print(f"Failed to create directory '{output_dir}'.")

# Load the saved CSV files from the directory to verify its contents
saved_df = spark.read.csv(output_dir, header=True, inferSchema=True)

# Show the contents of the saved DataFrame
saved_df.show()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Annual Income (k$): double (nullable = true)
#  |-- Spending Score (1-100): integer (nullable = true)
#
# +-------+------------------+------+-----------------+------------------+----------------------+
# |summary|        CustomerID|Gender|              Age|Annual Income (k$)|Spending Score (1-100)|
# +-------+------------------+------+-----------------+------------------+----------------------+
# |  count|               200|   200|              200|               200|                   200|
# |   mean|             100.5|  NULL|            38.85|             60.56|                  50.2|
# | stddev|57.879184513951124|  NULL|13.96900733155888| 26.26472116527124|    25.823521668370173|
# |    min|                 1|Female|               18|              15.0|                     1|
# ...

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when
import matplotlib.pyplot as plt

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .getOrCreate()

# Load the processed dataset
output_dir = "processed_data_output"
df = spark.read.csv(output_dir, header=True, inferSchema=True)

# Show schema to verify data types
df.printSchema()

# Show basic statistics
df.describe().show()

# Count the number of male and female customers
gender_count = df.groupBy("Gender").count()
gender_count.show()

# Calculate the average spending score for each gender
average_spending_score = df.groupBy("Gender").avg("Spending Score (1-100)")
average_spending_score.show()

# Collect data for plotting the distribution of spending scores
spending_scores = df.select("Spending Score (1-100)").collect()
spending_scores = [row["Spending Score (1-100)"] for row in spending_scores]

# Plot the distribution
plt.hist(spending_scores, bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('Spending Score (1-100)')
plt.ylabel('Frequency')
plt.title('Distribution of Spending Scores')
plt.show()

# Calculate the average annual income for each age category
average_income_by_age_category = df.groupBy("Age Category").avg("Annual Income (k$)")
average_income_by_age_category.show()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Annual Income (k$): double (nullable = true)
#  |-- Spending Score (1-100): integer (nullable = true)
#  |-- Age Category: string (nullable = true)
#
# +-------+------------------+------+-----------------+------------------+----------------------+------------+
# |summary|        CustomerID|Gender|              Age|Annual Income (k$)|Spending Score (1-100)|Age Category|
# +-------+------------------+------+-----------------+------------------+----------------------+------------+
# |  count|               200|   200|              200|               200|                   200|         200|
# |   mean|             100.5|  NULL|            38.85|             60.56|                  50.2|        NULL|
# | stddev|57.879184513951124|  NULL|13.96900733155888| 26.26472116527124|    25.823521668370173|        NULL|
# ...

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans

# Select features for clustering
assembler = VectorAssembler(
    inputCols=["Annual Income (k$)", "Spending Score (1-100)"],
    outputCol="features")

# Transform the data
data_with_features = assembler.transform(df)

# Train a KMeans model
kmeans = KMeans(k=5, seed=1)
model = kmeans.fit(data_with_features)

# Make predictions
predictions = model.transform(data_with_features)

# Show the results
predictions.select("CustomerID", "Gender", "Age", "Annual Income (k$)", "Spending Score (1-100)", "prediction").show()

# Visualize the clusters
import pandas as pd

# Convert to Pandas DataFrame for visualization
predictions_pd = predictions.select("Annual Income (k$)", "Spending Score (1-100)", "prediction").toPandas()

plt.scatter(predictions_pd["Annual Income (k$)"], predictions_pd["Spending Score (1-100)"], c=predictions_pd["prediction"], cmap='viridis')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Customer Segments')
plt.show()
# Out:
# +----------+------+---+------------------+----------------------+----------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|prediction|
# +----------+------+---+------------------+----------------------+----------+
# |         1|  Male| 19|              15.0|                    39|         4|
# |         2|  Male| 21|              15.0|                    81|         2|
# |         3|Female| 20|              16.0|                     6|         4|
# |         4|Female| 23|              16.0|                    77|         2|
# |         5|Female| 31|              17.0|                    40|         4|
# |         6|Female| 22|              17.0|                    76|         2|
# |         7|Female| 35|              18.0|                     6|         4|
# |         8|Female| 23|              18.0|                    94|         2|
# |         9|  Male| 64|              19.0|                     3|         4|
# ...

# %%
# Calculate correlations
corr_matrix = df.select("Age", "Annual Income (k$)", "Spending Score (1-100)").toPandas().corr()

# Plot the correlation matrix
import seaborn as sns

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd

# Convert the Spark DataFrame to a Pandas DataFrame
df_pd = df.toPandas()

# Visualize the distribution of Annual Income
plt.figure(figsize=(10, 6))
sns.histplot(df_pd["Annual Income (k$)"], kde=True)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Frequency')
plt.show()

# Visualize the relationship between Age and Spending Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pd, x="Age", y="Spending Score (1-100)", hue="Gender")
plt.title('Age vs Spending Score by Gender')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans
import pandas as pd
import numpy as np

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Customer Segmentation") \
    .getOrCreate()

# Load the processed dataset
output_dir = "processed_data_output"
df = spark.read.csv(output_dir, header=True, inferSchema=True)

# Show schema to verify data types
df.printSchema()

# 1. Customer Segmentation using K-Means Clustering
assembler = VectorAssembler(
    inputCols=["Annual Income (k$)", "Spending Score (1-100)"],
    outputCol="features")
data_with_features = assembler.transform(df)
kmeans = KMeans(k=5, seed=1)
model = kmeans.fit(data_with_features)
predictions = model.transform(data_with_features)
predictions.select("CustomerID", "Gender", "Age", "Annual Income (k$)", "Spending Score (1-100)", "prediction").show()

# Visualize the clusters
predictions_pd = predictions.select("Annual Income (k$)", "Spending Score (1-100)", "prediction").toPandas()

# Handling infinite values
predictions_pd.replace([np.inf, -np.inf], np.nan, inplace=True)

plt.scatter(predictions_pd["Annual Income (k$)"], predictions_pd["Spending Score (1-100)"], c=predictions_pd["prediction"], cmap='viridis')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Customer Segments')
plt.show()

# 2. Analyzing Correlations
corr_matrix = df.select("Age", "Annual Income (k$)", "Spending Score (1-100)").toPandas().corr()

# Handling infinite values
corr_matrix.replace([np.inf, -np.inf], np.nan, inplace=True)

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# 3. Visualization using PySpark and Pandas
df_pd = df.toPandas()

# Handling infinite values
df_pd.replace([np.inf, -np.inf], np.nan, inplace=True)

# Distribution of Annual Income
plt.figure(figsize=(10, 6))
sns.histplot(df_pd["Annual Income (k$)"], kde=True)
plt.title('Distribution of Annual Income')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Frequency')
plt.show()

# Age vs Spending Score by Gender
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pd, x="Age", y="Spending Score (1-100)", hue="Gender")
plt.title('Age vs Spending Score by Gender')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Annual Income (k$): double (nullable = true)
#  |-- Spending Score (1-100): integer (nullable = true)
#  |-- Age Category: string (nullable = true)
#
# +----------+------+---+------------------+----------------------+----------+
# |CustomerID|Gender|Age|Annual Income (k$)|Spending Score (1-100)|prediction|
# +----------+------+---+------------------+----------------------+----------+
# |         1|  Male| 19|              15.0|                    39|         4|
# |         2|  Male| 21|              15.0|                    81|         2|
# |         3|Female| 20|              16.0|                     6|         4|
# |         4|Female| 23|              16.0|                    77|         2|
# |         5|Female| 31|              17.0|                    40|         4|
# |         6|Female| 22|              17.0|                    76|         2|
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the scatter plot with trend lines
plt.figure(figsize=(10, 6))

# Scatter plot
sns.scatterplot(data=df_pd, x="Age", y="Spending Score (1-100)", hue="Gender", alpha=0.6)

# Trend lines for each gender
sns.regplot(data=df_pd[df_pd["Gender"] == "Male"], x="Age", y="Spending Score (1-100)", scatter=False, label='Male', color='blue')
sns.regplot(data=df_pd[df_pd["Gender"] == "Female"], x="Age", y="Spending Score (1-100)", scatter=False, label='Female', color='orange')

# Add labels and title
plt.title('Age vs Spending Score by Gender')
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Gender')
plt.show()
